# %%
import os
import pandas as pd

# %% [markdown]
# Text Cleaning (lowercase, punctuation)

# %% [markdown]
# Translation (Malay -> English, deep-translator)

# %% [markdown]
# Stopword Removal (remove the, is, and, a, to)

# %% [markdown]
# Normalisation

# %% [markdown]
# Tokenization

# %% [markdown]
# Duplicate Removal

# %% [markdown]
# Combine all 4 CSVs into master dataset

# %% [markdown]
# Split train and test

# %% [markdown]
# Saved reviews_master_clean.csv

# %% [markdown]
# Saved preprocessing.py

# %% [markdown]
# Before and After Examples for Report
